# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
whale_returns_csv = Path("Resources/whale_returns.csv")
algo_returns_csv = Path("Resources/algo_returns.csv")
sp500_history_csv = Path("Resources/sp500_history.csv")

# %%
whale_returns = pd.read_csv(whale_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
algo_returns = pd.read_csv(algo_returns_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
sp500_history = pd.read_csv(sp500_history_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)

# %%
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
whale_returns.dropna(inplace=True)
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
algo_returns.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
algo_returns.dropna(inplace=True)
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
sp500_history.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
sp500_history['Close'] = sp500_history['Close'].str.replace('$', '')
sp500_history['Close'] = sp500_history['Close'].astype('float')
sp500_history.dtypes
# Out:
# Close    float64
# dtype: object

# %%
sp500_returns = sp500_history.pct_change()
sp500_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
sp500_returns.dropna(inplace=True)
sp500_returns.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
sp500_returns.head()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
combined_data = pd.concat([whale_returns,algo_returns,sp500_returns], axis = 'columns', join='inner')
combined_data.rename(columns={'Close':'S&P 500'}, inplace=True)
combined_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949  0.004408
# 2015-03-04  0.002416 -0.001195
# 2015-03-05  0.004323  0.014378
# ...

# %%
combined_data.plot(figsize=(20,10), title="Daily returns")

# %%
cumulative_returns = (1+combined_data).cumprod()
cumulative_returns.plot(figsize=(20,10), title='Cumulative returns')

# %%
combined_data.boxplot(figsize=(20,10))

# %%
daily_return_std = combined_data.std()
daily_return_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# S&P 500                        0.008587
# dtype: float64

# %%
daily_return_std>daily_return_std['S&P 500']
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# S&P 500                        False
# dtype: bool

# %%
daily_return_annualized_std = daily_return_std * np.sqrt(252)
daily_return_annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# Algo 2                         0.132413
# S&P 500                        0.136313
# dtype: float64

# %%
sp500_rolling_std = combined_data['S&P 500'].rolling(window=21).std()
sp500_rolling_std.plot(figsize=(20, 10), title="S&P 500 21 day rolling standard deviation")

# %%
corr_table = combined_data.corr()
corr_table
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# S&P 500                                       0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %%
rolling_covar = combined_data['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(combined_data['S&P 500'])
rolling_var = combined_data['S&P 500'].rolling(window=60).var()
rolling_beta = rolling_covar/rolling_var
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-day Beta of BERKSHIRE HATHAWAY INC')

# %%
ewm_average = combined_data.ewm(halflife=21, adjust=False).mean()
ewm_average.plot(figsize=(20, 10), title='Exponentially weighted average')

# %%
sharp_ratio = combined_data.mean()*252/(combined_data.std()*np.sqrt(252))
sharp_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# S&P 500                       -0.518582
# dtype: float64

# %%
sharp_ratio.plot(kind='bar', title='Sharp Ratios')

# %%
google_stock = pd.read_csv('Resources/goog_historical.csv', index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
google_stock.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
apple_stock = pd.read_csv('Resources/aapl_historical.csv', index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
apple_stock.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
cost_stock = pd.read_csv('Resources/cost_historical.csv', index_col="Trade DATE", infer_datetime_format=True, parse_dates=True)
cost_stock.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
combined_stock = pd.concat([google_stock,apple_stock,cost_stock], axis='rows', join='inner')
combined_stock.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
combined_stock.reset_index(inplace=True)
combined_stock.head()
# Out:
#   Trade DATE Symbol     NOCP
# 0 2019-05-09   GOOG  1162.38
# 1 2019-05-08   GOOG  1166.27
# 2 2019-05-07   GOOG  1174.10
# 3 2019-05-06   GOOG  1189.39
# 4 2019-05-03   GOOG  1185.40

# %%
new_table = pd.pivot_table(combined_stock, index='Trade DATE', columns=['Symbol'], values=['NOCP'])
new_table.head()
# Out:
#               NOCP
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
new_table = new_table.pct_change()
new_table.dropna(inplace=True)
new_table.head()
# Out:
#                 NOCP
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %%
weights = [1/3, 1/3, 1/3]
portfolio_return = new_table.dot(weights)
portfolio_return.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %%
new_data = pd.concat([combined_data, portfolio_return], axis='columns', join='outer')
new_data.rename(columns={0:'Custom'}, inplace=True)
new_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500  Custom
# 2015-03-03 -0.000949  0.004408     NaN
# 2015-03-04  0.002416 -0.001195     NaN
# 2015-03-05  0.004323  0.014378     NaN
# ...

# %%
new_data = pd.concat([combined_data, portfolio_return], axis='columns', join='inner')
new_data.rename(columns={0:'Custom'}, inplace=True)
new_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# 2018-05-18                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2   S&P 500    Custom
# 2018-05-14  0.001635  0.006889  0.000015
# 2018-05-15 -0.001139 -0.004044 -0.010064
# 2018-05-16  0.003341  0.000857  0.009403
# ...

# %%
risk = new_data.std()*np.sqrt(252)
risk
# Out:
# SOROS FUND MANAGEMENT LLC      0.146812
# PAULSON & CO.INC.              0.116928
# TIGER GLOBAL MANAGEMENT LLC    0.232898
# BERKSHIRE HATHAWAY INC         0.247305
# Algo 1                         0.133927
# Algo 2                         0.139499
# S&P 500                        0.152469
# Custom                         0.211627
# dtype: float64

# %%
new_data_rolling_std = new_data.rolling(window=21).std()
new_data_rolling_std.plot(figsize=(20, 10), title='21 rolling standard deviation')

# %%
custom_rolling_covar = new_data['Custom'].rolling(window=60).cov(new_data['S&P 500'])
sp500_rollling_var = new_data['S&P 500'].rolling(window=60).var()
custom_rolling_beta = custom_rolling_covar/sp500_rollling_var
custom_rolling_beta.plot(figsize=(20, 10), title='Custom stock 60-day rolling Beta')

# %%
annulized_returns = new_data.mean()*252
annual_sharp = annulized_returns/risk
annual_sharp
# Out:
# SOROS FUND MANAGEMENT LLC      0.380007
# PAULSON & CO.INC.              0.227577
# TIGER GLOBAL MANAGEMENT LLC   -1.066635
# BERKSHIRE HATHAWAY INC         0.103006
# Algo 1                         2.001260
# Algo 2                         0.007334
# S&P 500                       -0.427676
# Custom                         0.876152
# dtype: float64

# %%
annual_sharp.plot(kind='bar', title='Sharp Ratio')

# %%
new_corr_table = new_data.corr()
new_corr_table
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.791802
# PAULSON & CO.INC.                             0.791802            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.477844            0.484869
# BERKSHIRE HATHAWAY INC                        0.816197            0.650390
# Algo 1                                        0.336909            0.360727
# Algo 2                                        0.862583            0.783865
# S&P 500                                      -0.028256           -0.059862
# Custom                                        0.732548            0.643828
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.477844
# PAULSON & CO.INC.                               0.484869
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.324306
# ...
